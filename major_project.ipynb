# %% [markdown]
# <a href="https://colab.research.google.com/github/jeramiah713/v8/blob/main/major_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Oct 12 15:26:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME =os.getcwd()
print (HOME)
# Out:
# /content

# %%
# !pip uninstall ultralytics
# Out:
# Found existing installation: ultralytics 8.0.196
# Uninstalling ultralytics-8.0.196:
#   Would remove:
#     /usr/local/bin/ultralytics
#     /usr/local/bin/yolo
#     /usr/local/lib/python3.10/dist-packages/ultralytics-8.0.196.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/ultralytics/*
# Proceed (Y/n)? y
#   Successfully uninstalled ultralytics-8.0.196

# %%
# !pip install ultralytics

from IPython import display

# !yolo mode=checks
# Out:
# ...
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 393, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark').
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="/content/dog2.jpg"
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/dog2.jpg: 448x640 1 person, 1 dog, 212.1ms
# Speed: 5.7ms preprocess, 212.1ms inference, 14.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename="runs/detect/predict2/dog2.jpg",height=200)
# Out:
# /content

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="/content/people.jpg"
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/people.jpg: 288x640 2 persons, 102.5ms
# Speed: 2.2ms preprocess, 102.5ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename="runs/detect/predict3/people.jpg",height=200)
# Out:
# /content

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="/content/cars.jpg"
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/cars.jpg: 352x640 1 car, 101.1ms
# Speed: 2.8ms preprocess, 101.1ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename="runs/detect/predict4/cars.jpg",height=200)
# Out:
# /content

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="/content/profile.jpg"
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/profile.jpg: 640x640 1 person, 1 cell phone, 9.5ms
# Speed: 3.3ms preprocess, 9.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !wget https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x.pt

# %%
model = YOLO("yolov8x.pt")

# %%
results = model(sorce = 'image_path', save = True, conf = 0.4)
